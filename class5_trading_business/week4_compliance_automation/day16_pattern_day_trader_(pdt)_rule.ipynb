# %% [markdown]
# # Day 16: Pattern Day Trader (PDT) Rule
#
# **Class 5: Trading Business & Advanced Topics** | Week 4: Compliance & Automation
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/astoreyai/money-talks/blob/main/class5_trading_business/week4_compliance_automation/day16_pattern_day_trader_(pdt)_rule.ipynb)
#
# ---
#
# ## Learning Objectives
#
# By the end of this lesson, you will be able to:
#
# 1. Understand the Pattern Day Trader rule
# 2. Calculate the $25,000 minimum equity requirement
# 3. Identify strategies to avoid PDT classification
# 4. Know the consequences of PDT violations
# 5. Use cash accounts vs. margin accounts strategically

# %% [markdown]
# ---
#
# # LECTURE SECTION (30 minutes)
#
# ---

# %% [markdown]
# ## Pattern Day Trader (PDT) Rule Overview
#
# This lesson covers key concepts in pattern day trader (pdt) rule.

# %% [markdown]
# ---
#
# # HANDS-ON SECTION (15 minutes)
#
# ---

# %%
# Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print('Setup complete!')

# %% [markdown]
# ---
#
# # QUIZ SECTION
#
# ---

# %%
quiz_questions = [
    {'question': f'1. What is {title}?', 'options': ['A) Option A', 'B) Option B', 'C) Option C', 'D) Option D'], 'answer': 'B'},
    {'question': '2. Question 2?', 'options': ['A) Answer A', 'B) Answer B', 'C) Answer C', 'D) Answer D'], 'answer': 'B'},
    {'question': '3. Question 3?', 'options': ['A) Answer A', 'B) Answer B', 'C) Answer C', 'D) Answer D'], 'answer': 'C'},
    {'question': '4. Question 4?', 'options': ['A) Answer A', 'B) Answer B', 'C) Answer C', 'D) Answer D'], 'answer': 'A'},
    {'question': '5. Question 5?', 'options': ['A) Answer A', 'B) Answer B', 'C) Answer C', 'D) Answer D'], 'answer': 'D'}
]

print('='*50)
print(f'  Day {day_num} Quiz: {title}')
print('='*50 + '\n')

score = 0
for q in quiz_questions:
    print(q['question'])
    for opt in q['options']:
        print(f'  {opt}')
    answer = input('Your answer: ').strip().upper()
    if answer == q['answer']:
        print('✓ Correct!\n')
        score += 1
    else:
        print(f"✗ Incorrect. The correct answer was {q['answer']}.\n")

print('='*50)
print(f'  Final Score: {score}/{len(quiz_questions)} ({score/len(quiz_questions)*100:.0f}%)')
print('='*50)

# %% [markdown]
# ---
#
# ## Summary
#
# Today you learned key concepts about pattern day trader (pdt) rule.
#
# ## Next Lesson
#
# **Day 17: Margin Requirements & Regulation T**
#
# ---
#
# *Money Talks: Trading & Investing Education*
